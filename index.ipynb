# %% [markdown]
# # Data Analysis in Pandas - Introduction

# %%
# Import pandas library
import pandas as pd
# Import/ Load data
data = pd.read_csv('housing.csv') # pd.read_excel ('housing.xlsx')

# %%
# Load data using csv.DictReader to pandas
import pandas as pd

df = pd.read_csv('olympic_medals.csv')
df.head(3)
# Out:
#   Gender       Event Location  Year Medal                   Name Nationality  \
# 0      M  10000M Men      Rio  2016     G          Mohamed FARAH         GBR
# 1      M  10000M Men      Rio  2016     S  Paul Kipngetich TANUI         KEN
# 2      M  10000M Men      Rio  2016     B           Tamirat TOLA         ETH
#
#      Result
# 0  25:05.17
# 1  27:05.64
# 2  27:06.26

# %%
# load the data using csv.DictReader
import csv 
with open('olympic_medals.csv', encoding="utf8") as f:
    reader = csv.DictReader(f)
    olympics_data = list(reader)
for index in range(5):
    print(olympics_data[index])
# Out:
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Rio', 'Year': '2016', 'Medal': 'G', 'Name': 'Mohamed FARAH', 'Nationality': 'GBR', 'Result': '25:05.17'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Rio', 'Year': '2016', 'Medal': 'S', 'Name': 'Paul Kipngetich TANUI', 'Nationality': 'KEN', 'Result': '27:05.64'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Rio', 'Year': '2016', 'Medal': 'B', 'Name': 'Tamirat TOLA', 'Nationality': 'ETH', 'Result': '27:06.26'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Beijing', 'Year': '2008', 'Medal': 'G', 'Name': 'Kenenisa BEKELE', 'Nationality': 'ETH', 'Result': '27:01.17'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Beijing', 'Year': '2008', 'Medal': 'S', 'Name': 'Sileshi SIHINE', 'Nationality': 'ETH', 'Result': '27:02.77'}

# %%
olympics_data
# Out:
# [{'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'G',
#   'Name': 'Mohamed FARAH',
#   'Nationality': 'GBR',
#   'Result': '25:05.17'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'S',
#   'Name': 'Paul Kipngetich TANUI',
#   'Nationality': 'KEN',
#   'Result': '27:05.64'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'B',
#   'Name': 'Tamirat TOLA',
#   'Nationality': 'ETH',
#   'Result': '27:06.26'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'G',
#   'Name': 'Kenenisa BEKELE',
#   'Nationality': 'ETH',
#   'Result': '27:01.17'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'S',
#   'Name': 'Sileshi SIHINE',
#   'Nationality': 'ETH',
#   'Result': '27:02.77'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'B',
#   'Name': 'Micah KOGO',
#   'Nationality': 'KEN',
#   'Result': '27:04.11'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'G',
#   'Name': 'Haile GEBRSELASSIE',
#   'Nationality': 'ETH',
#   'Result': '27:18.20'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'S',
#   'Name': 'Paul TERGAT',
#   'Nationality': 'KEN',
#   'Result': '27:18.29'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'B',
#   'Name': 'Assefa MEZGEBU',
#   'Nationality': 'ETH',
#   'Result': '27:19.75'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'G',
#   'Name': 'Khalid SKAH',
#   'Nationality': 'MAR',
#   'Result': '27:46.70'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'S',
#   'Name': 'Richard CHELIMO',
#   'Nationality': 'KEN',
#   'Result': '27:47.72'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'B',
#   'Name': 'Addis ABEBE',
#   'Nationality': 'ETH',
#   'Result': '28:00.07'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'G',
#   'Name': 'Alberto COVA',
#   'Nationality': 'ITA',
#   'Result': '27:47.54'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'S',
#   'Name': 'Michael MCLEOD',
#   'Nationality': 'GBR',
#   'Result': '28:06.22'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'B',
#   'Name': 'Michael MUSYOKI',
#   'Nationality': 'KEN',
#   'Result': '28:06.46'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'G',
#   'Name': 'Lasse VIREN',
#   'Nationality': 'FIN',
#   'Result': '27:40.38'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'S',
#   'Name': 'Carlos LOPES',
#   'Nationality': 'POR',
#   'Result': '27:45.17'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'B',
#   'Name': 'Brendan FOSTER',
#   'Nationality': 'GBR',
#   'Result': '27:54.92'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'G',
#   'Name': 'Naftali TEMU',
#   'Nationality': 'KEN',
#   'Result': '29:27.4'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'S',
#   'Name': 'Mamo WOLDE',
#   'Nationality': 'ETH',
#   'Result': '29:28.0'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'B',
#   'Name': 'Mohamed GAMMOUDI',
#   'Nationality': 'TUN',
#   'Result': '29:34.2'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'G',
#   'Name': 'Pyotr BOLOTNIKOV',
#   'Nationality': 'URS',
#   'Result': '28:32.2'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'S',
#   'Name': 'Hans GRODOTZKI',
#   'Nationality': 'EUA',
#   'Result': '28:37.0'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'B',
#   'Name': 'David POWER',
#   'Nationality': 'AUS',
#   'Result': '28:38.2'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'G',
#   'Name': 'Emil ZÃ\x81TOPEK',
#   'Nationality': 'TCH',
#   'Result': '29:17.0'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'S',
#   'Name': 'Alain MIMOUN',
#   'Nationality': 'FRA',
#   'Result': '29:32.8'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'B',
#   'Name': 'Aleksandr ANUFRIYEV',
#   'Nationality': 'URS',
#   'Result': '29:48.2'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'G',
#   'Name': 'Ilmari SALMINEN',
#   'Nationality': 'FIN',
#   'Result': '30:15.4'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'S',
#   'Name': 'Arvo ASKOLA',
#   'Nationality': 'FIN',
#   'Result': '30:15.6'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'B',
#   'Name': 'Volmari ISO-HOLLO',
#   'Nationality': 'FIN',
#   'Result': '30:20.2'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'G',
#   'Name': 'Paavo NURMI',
#   'Nationality': 'FIN',
#   'Result': '30:18.8'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'S',
#   'Name': 'Ville RITOLA',
#   'Nationality': 'FIN',
#   'Result': '30:19.4'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'B',
#   'Name': 'Edvin WIDE',
#   'Nationality': 'SWE',
#   'Result': '31:00.8'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'G',
#   'Name': 'Paavo NURMI',
#   'Nationality': 'FIN',
#   'Result': '31:45.8'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'S',
#   'Name': 'Joseph GUILLEMOT',
#   'Nationality': 'FRA',
#   'Result': '31:47.2'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'B',
#   'Name': 'James WILSON',
#   'Nationality': 'GBR',
#   'Result': '31:50.8'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'London',
#   'Year': '2012',
#   'Medal': 'G',
#   'Name': 'Mohamed FARAH',
#   'Nationality': 'GBR',
#   'Result': '27:30.42'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'London',
#   'Year': '2012',
#   'Medal': 'S',
#   'Name': 'Galen RUPP',
#   'Nationality': 'USA',
#   'Result': '27:30.90'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'London',
#   'Year': '2012',
#   'Medal': 'B',
#   'Name': 'Tariku BEKELE',
#   'Nationality': 'ETH',
#   'Result': '27:31.43'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Athens',
#   'Year': '2004',
#   'Medal': 'G',
#   'Name': 'Kenenisa BEKELE',
#   'Nationality': 'ETH',
#   'Result': '27:05.10'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Athens',
#   'Year': '2004',
#   'Medal': 'S',
#   'Name': 'Sileshi SIHINE',
#   'Nationality': 'ETH',
#   'Result': '27:09.39'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Athens',
#   'Year': '2004',
#   'Medal': 'B',
#   'Name': 'Zersenay TADESE',
#   'Nationality': 'ERI',
#   'Result': '27:22.57'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Atlanta',
#   'Year': '1996',
#   'Medal': 'G',
#   'Name': 'Haile GEBRSELASSIE',
#   'Nationality': 'ETH',
#   'Result': '27:07.34'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Atlanta',
#   'Year': '1996',
#   'Medal': 'S',
#   'Name': 'Paul TERGAT',
#   'Nationality': 'KEN',
#   'Result': '27:08.17'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Atlanta',
#   'Year': '1996',
#   'Medal': 'B',
#   'Name': 'Salah HISSOU',
#   'Nationality': 'MAR',
#   'Result': '27:24.67'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'G',
#   'Name': 'Miruts YIFTER',
#   'Nationality': 'ETH',
#   'Result': '27:42.7'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'S',
#   'Name': 'Kaarlo MAANINKA',
#   'Nationality': 'FIN',
#   'Result': '27:44.3'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'B',
#   'Name': 'Mohammed KEDIR',
#   'Nationality': 'ETH',
#   'Result': '27:44.7'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Munich',
#   'Year': '1972',
#   'Medal': 'G',
#   'Name': 'Lasse VIREN',
#   'Nationality': 'FIN',
#   'Result': '27:38.35'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Munich',
#   'Year': '1972',
#   'Medal': 'S',
#   'Name': 'Emiel PUTTEMANS',
#   'Nationality': 'BEL',
#   'Result': '27:39.58'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Munich',
#   'Year': '1972',
#   'Medal': 'B',
#   'Name': 'Miruts YIFTER',
#   'Nationality': 'ETH',
#   'Result': '27:40.96'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Tokyo',
#   'Year': '1964',
#   'Medal': 'G',
#   'Name': 'Billy MILLS',
#   'Nationality': 'USA',
#   'Result': '28:24.4'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Tokyo',
#   'Year': '1964',
#   'Medal': 'S',
#   'Name': 'Mohamed GAMMOUDI',
#   'Nationality': 'TUN',
#   'Result': '28:24.8'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Tokyo',
#   'Year': '1964',
#   'Medal': 'B',
#   'Name': 'Ron CLARKE',
#   'Nationality': 'AUS',
#   'Result': '28:25.8'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Melbourne / Stockholm',
#   'Year': '1956',
#   'Medal': 'G',
#   'Name': 'Vladimir KUTS',
#   'Nationality': 'URS',
#   'Result': '28:45.6'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Melbourne / Stockholm',
#   'Year': '1956',
#   'Medal': 'S',
#   'Name': 'JÃ³zsef KOVÃ\x81CS',
#   'Nationality': 'HUN',
#   'Result': '28:52.4'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Melbourne / Stockholm',
#   'Year': '1956',
#   'Medal': 'B',
#   'Name': 'Allan LAWRENCE',
#   'Nationality': 'AUS',
#   'Result': '28:53.6'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'London',
#   'Year': '1948',
#   'Medal': 'G',
#   'Name': 'Emil ZÃ\x81TOPEK',
#   'Nationality': 'TCH',
#   'Result': '29:59.6'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'London',
#   'Year': '1948',
#   'Medal': 'S',
#   'Name': 'Alain MIMOUN',
#   'Nationality': 'FRA',
#   'Result': '30:47.4'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'London',
#   'Year': '1948',
#   'Medal': 'B',
#   'Name': 'Bertil ALBERTSSON',
#   'Nationality': 'SWE',
#   'Result': '30:53.6'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Los Angeles',
#   'Year': '1932',
#   'Medal': 'G',
#   'Name': 'Janusz KUSOCINSKI',
#   'Nationality': 'POL',
#   'Result': '30:11.4'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Los Angeles',
#   'Year': '1932',
#   'Medal': 'S',
#   'Name': 'Volmari ISO-HOLLO',
#   'Nationality': 'FIN',
#   'Result': '30:12.6'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Los Angeles',
#   'Year': '1932',
#   'Medal': 'B',
#   'Name': 'Lauri VIRTANEN',
#   'Nationality': 'FIN',
#   'Result': '30:35.0'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Paris',
#   'Year': '1924',
#   'Medal': 'G',
#   'Name': 'Ville RITOLA',
#   'Nationality': 'FIN',
#   'Result': '30:23.2'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Paris',
#   'Year': '1924',
#   'Medal': 'S',
#   'Name': 'Edvin WIDE',
#   'Nationality': 'SWE',
#   'Result': '30:55.2'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Paris',
#   'Year': '1924',
#   'Medal': 'B',
#   'Name': 'Eero BERG',
#   'Nationality': 'FIN',
#   'Result': '31:43.0'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Stockholm',
#   'Year': '1912',
#   'Medal': 'G',
#   'Name': 'Hannes KOLEHMAINEN',
#   'Nationality': 'FIN',
#   'Result': '31:20.8'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Stockholm',
#   'Year': '1912',
#   'Medal': 'S',
#   'Name': 'Lewis TEWANIMA',
#   'Nationality': 'USA',
#   'Result': '32:06.6'},
#  {'Gender': 'M',
#   'Event': '10000M Men',
#   'Location': 'Stockholm',
#   'Year': '1912',
#   'Medal': 'B',
#   'Name': 'Albin STENROOS',
#   'Nationality': 'FIN',
#   'Result': '32:21.8'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'G',
#   'Name': 'Usain BOLT',
#   'Nationality': 'JAM',
#   'Result': '9.81'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'S',
#   'Name': 'Justin GATLIN',
#   'Nationality': 'USA',
#   'Result': '9.89'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'B',
#   'Name': 'Andre DE GRASSE',
#   'Nationality': 'CAN',
#   'Result': '9.91'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'G',
#   'Name': 'Usain BOLT',
#   'Nationality': 'JAM',
#   'Result': '9.69'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'S',
#   'Name': 'Richard THOMPSON',
#   'Nationality': 'TTO',
#   'Result': '9.89'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'B',
#   'Name': 'Walter DIX',
#   'Nationality': 'USA',
#   'Result': '9.91'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'G',
#   'Name': 'Maurice GREENE',
#   'Nationality': 'USA',
#   'Result': '9.87'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'S',
#   'Name': 'Ato BOLDON',
#   'Nationality': 'TTO',
#   'Result': '9.99'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'B',
#   'Name': 'Obadele THOMPSON',
#   'Nationality': 'BAR',
#   'Result': '10.04'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'G',
#   'Name': 'Linford CHRISTIE',
#   'Nationality': 'GBR',
#   'Result': '9.96'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'S',
#   'Name': 'Frank FREDERICKS',
#   'Nationality': 'NAM',
#   'Result': '10.02'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'B',
#   'Name': 'Dennis MITCHELL',
#   'Nationality': 'USA',
#   'Result': '10.04'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'G',
#   'Name': 'Carl LEWIS',
#   'Nationality': 'USA',
#   'Result': '9.99'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'S',
#   'Name': 'Sam GRADDY',
#   'Nationality': 'USA',
#   'Result': '10.19'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'B',
#   'Name': 'Ben JOHNSON',
#   'Nationality': 'CAN',
#   'Result': '10.22'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'G',
#   'Name': 'Hasely CRAWFORD',
#   'Nationality': 'TTO',
#   'Result': '10.06'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'S',
#   'Name': 'Donald QUARRIE',
#   'Nationality': 'JAM',
#   'Result': '10.08'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'B',
#   'Name': 'Valery BORZOV',
#   'Nationality': 'URS',
#   'Result': '10.14'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'G',
#   'Name': 'Jim HINES',
#   'Nationality': 'USA',
#   'Result': '9.9'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'S',
#   'Name': 'Lennox MILLER',
#   'Nationality': 'JAM',
#   'Result': '10.0'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'B',
#   'Name': 'Charlie GREENE',
#   'Nationality': 'USA',
#   'Result': '10.0'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'G',
#   'Name': 'Armin HARY',
#   'Nationality': 'EUA',
#   'Result': '10.2'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'S',
#   'Name': 'Dave SIME',
#   'Nationality': 'USA',
#   'Result': '10.2'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'B',
#   'Name': 'Peter RADFORD',
#   'Nationality': 'GBR',
#   'Result': '10.3'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'G',
#   'Name': 'Lindy REMIGINO',
#   'Nationality': 'USA',
#   'Result': '10.4'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'S',
#   'Name': 'Herbert MCKENLEY',
#   'Nationality': 'JAM',
#   'Result': '10.4'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'B',
#   'Name': 'Emmanuel McDONALD BAILEY',
#   'Nationality': 'GBR',
#   'Result': '10.4'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'G',
#   'Name': 'Jesse OWENS',
#   'Nationality': 'USA',
#   'Result': '10.3'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'S',
#   'Name': 'Ralph METCALFE',
#   'Nationality': 'USA',
#   'Result': '10.4'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'B',
#   'Name': 'Martinus OSENDARP',
#   'Nationality': 'NED',
#   'Result': '10.5'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'G',
#   'Name': 'Percy WILLIAMS',
#   'Nationality': 'CAN',
#   'Result': '10.8'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'S',
#   'Name': 'Jack LONDON',
#   'Nationality': 'GBR',
#   'Result': '10.9'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'B',
#   'Name': 'Georg LAMMERS',
#   'Nationality': 'GER',
#   'Result': '10.9'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'G',
#   'Name': 'Charles PADDOCK',
#   'Nationality': 'USA',
#   'Result': '10.8'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'S',
#   'Name': 'Morris KIRKSEY',
#   'Nationality': 'USA',
#   'Result': '10.8'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'B',
#   'Name': 'Harry EDWARD',
#   'Nationality': 'GBR',
#   'Result': '10.9'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'London',
#   'Year': '1908',
#   'Medal': 'G',
#   'Name': 'Reggie WALKER',
#   'Nationality': 'RSA',
#   'Result': '10.8'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'London',
#   'Year': '1908',
#   'Medal': 'S',
#   'Name': 'John RECTOR',
#   'Nationality': 'USA',
#   'Result': 'None'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'London',
#   'Year': '1908',
#   'Medal': 'B',
#   'Name': 'Robert KERR',
#   'Nationality': 'CAN',
#   'Result': 'None'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Paris',
#   'Year': '1900',
#   'Medal': 'G',
#   'Name': 'Frank JARVIS',
#   'Nationality': 'USA',
#   'Result': '11.0'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Paris',
#   'Year': '1900',
#   'Medal': 'S',
#   'Name': 'Walter TEWKSBURY',
#   'Nationality': 'USA',
#   'Result': '11.1'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Paris',
#   'Year': '1900',
#   'Medal': 'B',
#   'Name': 'Stanley ROWLEY',
#   'Nationality': 'AUS',
#   'Result': '11.2'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'London',
#   'Year': '2012',
#   'Medal': 'G',
#   'Name': 'Usain BOLT',
#   'Nationality': 'JAM',
#   'Result': '9.63'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'London',
#   'Year': '2012',
#   'Medal': 'S',
#   'Name': 'Yohan BLAKE',
#   'Nationality': 'JAM',
#   'Result': '9.75'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'London',
#   'Year': '2012',
#   'Medal': 'B',
#   'Name': 'Justin GATLIN',
#   'Nationality': 'USA',
#   'Result': '9.79'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Athens',
#   'Year': '2004',
#   'Medal': 'G',
#   'Name': 'Justin GATLIN',
#   'Nationality': 'USA',
#   'Result': '9.85'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Athens',
#   'Year': '2004',
#   'Medal': 'S',
#   'Name': 'Francis OBIKWELU',
#   'Nationality': 'POR',
#   'Result': '9.86'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Athens',
#   'Year': '2004',
#   'Medal': 'B',
#   'Name': 'Maurice GREENE',
#   'Nationality': 'USA',
#   'Result': '9.87'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Atlanta',
#   'Year': '1996',
#   'Medal': 'G',
#   'Name': 'Donovan BAILEY',
#   'Nationality': 'CAN',
#   'Result': '9.84'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Atlanta',
#   'Year': '1996',
#   'Medal': 'S',
#   'Name': 'Frank FREDERICKS',
#   'Nationality': 'NAM',
#   'Result': '9.89'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Atlanta',
#   'Year': '1996',
#   'Medal': 'B',
#   'Name': 'Ato BOLDON',
#   'Nationality': 'TTO',
#   'Result': '9.9'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'G',
#   'Name': 'Allan WELLS',
#   'Nationality': 'GBR',
#   'Result': '10.25'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'S',
#   'Name': 'Silvio LEONARD SARRIA',
#   'Nationality': 'CUB',
#   'Result': '10.25'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'B',
#   'Name': 'Peter PETROV',
#   'Nationality': 'BUL',
#   'Result': '10.39'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Munich',
#   'Year': '1972',
#   'Medal': 'G',
#   'Name': 'Valery BORZOV',
#   'Nationality': 'URS',
#   'Result': '10.14'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Munich',
#   'Year': '1972',
#   'Medal': 'S',
#   'Name': 'Robert TAYLOR',
#   'Nationality': 'USA',
#   'Result': '10.24'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Munich',
#   'Year': '1972',
#   'Medal': 'B',
#   'Name': 'Lennox MILLER',
#   'Nationality': 'JAM',
#   'Result': '10.33'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Tokyo',
#   'Year': '1964',
#   'Medal': 'G',
#   'Name': 'Bob HAYES',
#   'Nationality': 'USA',
#   'Result': '10.0'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Tokyo',
#   'Year': '1964',
#   'Medal': 'S',
#   'Name': 'Enrique FIGUEROLA',
#   'Nationality': 'CUB',
#   'Result': '10.2'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Tokyo',
#   'Year': '1964',
#   'Medal': 'B',
#   'Name': 'Harry JEROME',
#   'Nationality': 'CAN',
#   'Result': '10.2'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Melbourne / Stockholm',
#   'Year': '1956',
#   'Medal': 'G',
#   'Name': 'Bobby MORROW',
#   'Nationality': 'USA',
#   'Result': '10.5'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Melbourne / Stockholm',
#   'Year': '1956',
#   'Medal': 'S',
#   'Name': 'Thane BAKER',
#   'Nationality': 'USA',
#   'Result': '10.5'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Melbourne / Stockholm',
#   'Year': '1956',
#   'Medal': 'B',
#   'Name': 'Hector HOGAN',
#   'Nationality': 'AUS',
#   'Result': '10.6'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'London',
#   'Year': '1948',
#   'Medal': 'G',
#   'Name': 'Harrison DILLARD',
#   'Nationality': 'USA',
#   'Result': '10.3'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'London',
#   'Year': '1948',
#   'Medal': 'S',
#   'Name': 'Barney EWELL',
#   'Nationality': 'USA',
#   'Result': '10.4'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'London',
#   'Year': '1948',
#   'Medal': 'B',
#   'Name': 'Lloyd LABEACH',
#   'Nationality': 'PAN',
#   'Result': '10.6'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Los Angeles',
#   'Year': '1932',
#   'Medal': 'G',
#   'Name': 'Eddie TOLAN',
#   'Nationality': 'USA',
#   'Result': '10.3'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Los Angeles',
#   'Year': '1932',
#   'Medal': 'S',
#   'Name': 'Ralph METCALFE',
#   'Nationality': 'USA',
#   'Result': '10.3'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Los Angeles',
#   'Year': '1932',
#   'Medal': 'B',
#   'Name': 'Arthur JONATH',
#   'Nationality': 'GER',
#   'Result': '10.4'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Paris',
#   'Year': '1924',
#   'Medal': 'G',
#   'Name': 'Harold ABRAHAMS',
#   'Nationality': 'GBR',
#   'Result': '10.6'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Paris',
#   'Year': '1924',
#   'Medal': 'S',
#   'Name': 'Jackson SCHOLZ',
#   'Nationality': 'USA',
#   'Result': '10.7'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Paris',
#   'Year': '1924',
#   'Medal': 'B',
#   'Name': 'Arthur PORRITT',
#   'Nationality': 'NZL',
#   'Result': '10.8'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Stockholm',
#   'Year': '1912',
#   'Medal': 'G',
#   'Name': 'Ralph CRAIG',
#   'Nationality': 'USA',
#   'Result': '10.8'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Stockholm',
#   'Year': '1912',
#   'Medal': 'S',
#   'Name': 'Alvah MEYER',
#   'Nationality': 'USA',
#   'Result': '10.9'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Stockholm',
#   'Year': '1912',
#   'Medal': 'B',
#   'Name': 'Donald LIPPINCOTT',
#   'Nationality': 'USA',
#   'Result': '10.9'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'St Louis',
#   'Year': '1904',
#   'Medal': 'G',
#   'Name': 'Archie HAHN',
#   'Nationality': 'USA',
#   'Result': '11.0'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'St Louis',
#   'Year': '1904',
#   'Medal': 'S',
#   'Name': 'Nate CARTMELL',
#   'Nationality': 'USA',
#   'Result': '11.2'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'St Louis',
#   'Year': '1904',
#   'Medal': 'B',
#   'Name': 'William HOGENSON',
#   'Nationality': 'USA',
#   'Result': '11.2'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Athens',
#   'Year': '1896',
#   'Medal': 'G',
#   'Name': 'Thomas BURKE',
#   'Nationality': 'USA',
#   'Result': '12.0'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Athens',
#   'Year': '1896',
#   'Medal': 'S',
#   'Name': 'Fritz HOFMANN',
#   'Nationality': 'GER',
#   'Result': '12.2'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Athens',
#   'Year': '1896',
#   'Medal': 'B',
#   'Name': 'Alajos SZOKOLYI',
#   'Nationality': 'HUN',
#   'Result': '12.6'},
#  {'Gender': 'M',
#   'Event': '100M Men',
#   'Location': 'Athens',
#   'Year': '1896',
#   'Medal': 'B',
#   'Name': 'Francis LANE',
#   'Nationality': 'USA',
#   'Result': '12.6'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'G',
#   'Name': 'Omar MCLEOD',
#   'Nationality': 'JAM',
#   'Result': '13.05'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'S',
#   'Name': 'Orlando ORTEGA',
#   'Nationality': 'ESP',
#   'Result': '13.17'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'B',
#   'Name': 'Dimitri BASCOU',
#   'Nationality': 'FRA',
#   'Result': '13.24'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'G',
#   'Name': 'Dayron ROBLES',
#   'Nationality': 'CUB',
#   'Result': '12.93+0.1'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'S',
#   'Name': 'David PAYNE',
#   'Nationality': 'USA',
#   'Result': '13.17+0.1'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'B',
#   'Name': 'David OLIVER',
#   'Nationality': 'USA',
#   'Result': '13.18+0.1'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'G',
#   'Name': 'Anier GARCIA',
#   'Nationality': 'CUB',
#   'Result': '13.0'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'S',
#   'Name': 'Terrence TRAMMELL',
#   'Nationality': 'USA',
#   'Result': '13.16'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'B',
#   'Name': 'Mark CREAR',
#   'Nationality': 'USA',
#   'Result': '13.22'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'G',
#   'Name': 'Mark MCKOY',
#   'Nationality': 'CAN',
#   'Result': '13.12'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'S',
#   'Name': 'Tony DEES',
#   'Nationality': 'USA',
#   'Result': '13.24'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'B',
#   'Name': 'Jack PIERCE',
#   'Nationality': 'USA',
#   'Result': '13.26'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'G',
#   'Name': 'Roger KINGDOM',
#   'Nationality': 'USA',
#   'Result': '13.2'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'S',
#   'Name': 'Greg FOSTER',
#   'Nationality': 'USA',
#   'Result': '13.23'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'B',
#   'Name': 'Arto BRYGGARE',
#   'Nationality': 'FIN',
#   'Result': '13.4'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'G',
#   'Name': 'Guy DRUT',
#   'Nationality': 'FRA',
#   'Result': '13.3'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'S',
#   'Name': 'Alejandro CASAÃ\x91AS',
#   'Nationality': 'CUB',
#   'Result': '13.33'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'B',
#   'Name': 'Willie DAVENPORT',
#   'Nationality': 'USA',
#   'Result': '13.38'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'G',
#   'Name': 'Willie DAVENPORT',
#   'Nationality': 'USA',
#   'Result': '13.3'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'S',
#   'Name': 'Ervin HALL',
#   'Nationality': 'USA',
#   'Result': '13.4'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'B',
#   'Name': 'Eddy OTTOZ',
#   'Nationality': 'ITA',
#   'Result': '13.4'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'G',
#   'Name': 'Lee CALHOUN',
#   'Nationality': 'USA',
#   'Result': '13.8'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'S',
#   'Name': 'Willie MAY',
#   'Nationality': 'USA',
#   'Result': '13.8'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'B',
#   'Name': 'Hayes JONES',
#   'Nationality': 'USA',
#   'Result': '14.0'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'G',
#   'Name': 'Harrison DILLARD',
#   'Nationality': 'USA',
#   'Result': '13.7'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'S',
#   'Name': 'Jack DAVIS',
#   'Nationality': 'USA',
#   'Result': '13.7'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'B',
#   'Name': 'Arthur BARNARD',
#   'Nationality': 'USA',
#   'Result': '14.1'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'G',
#   'Name': 'Forrest TOWNS',
#   'Nationality': 'USA',
#   'Result': '14.2'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'S',
#   'Name': 'Donald FINLAY',
#   'Nationality': 'GBR',
#   'Result': '14.4'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'B',
#   'Name': 'Fritz POLLARD',
#   'Nationality': 'USA',
#   'Result': '14.4'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'G',
#   'Name': 'Sidney ATKINSON',
#   'Nationality': 'RSA',
#   'Result': '14.8'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'S',
#   'Name': 'Steve ANDERSON',
#   'Nationality': 'USA',
#   'Result': '14.8'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'B',
#   'Name': 'John COLLIER',
#   'Nationality': 'USA',
#   'Result': '14.9'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'G',
#   'Name': 'Earl THOMSON',
#   'Nationality': 'CAN',
#   'Result': '14.8'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'S',
#   'Name': 'Harold BARRON',
#   'Nationality': 'USA',
#   'Result': '15.1'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'B',
#   'Name': 'Frederick MURRAY',
#   'Nationality': 'USA',
#   'Result': '15.1'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'London',
#   'Year': '1908',
#   'Medal': 'G',
#   'Name': 'Forrest SMITHSON',
#   'Nationality': 'USA',
#   'Result': '15.0'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'London',
#   'Year': '1908',
#   'Medal': 'S',
#   'Name': 'John GARRELLS',
#   'Nationality': 'USA',
#   'Result': '15.7'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'London',
#   'Year': '1908',
#   'Medal': 'B',
#   'Name': 'Arthur SHAW',
#   'Nationality': 'USA',
#   'Result': 'None'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Paris',
#   'Year': '1900',
#   'Medal': 'G',
#   'Name': 'Alvin KRAENZLEIN',
#   'Nationality': 'USA',
#   'Result': '15.4'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Paris',
#   'Year': '1900',
#   'Medal': 'S',
#   'Name': 'John MCLEAN',
#   'Nationality': 'USA',
#   'Result': '15.5'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Paris',
#   'Year': '1900',
#   'Medal': 'B',
#   'Name': 'Frederick MOLONEY',
#   'Nationality': 'USA',
#   'Result': '15.6'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'London',
#   'Year': '2012',
#   'Medal': 'G',
#   'Name': 'Aries MERRITT',
#   'Nationality': 'USA',
#   'Result': '12.92'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'London',
#   'Year': '2012',
#   'Medal': 'S',
#   'Name': 'Jason RICHARDSON',
#   'Nationality': 'USA',
#   'Result': '13.04'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'London',
#   'Year': '2012',
#   'Medal': 'B',
#   'Name': 'Hansle PARCHMENT',
#   'Nationality': 'JAM',
#   'Result': '13.12'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Athens',
#   'Year': '2004',
#   'Medal': 'G',
#   'Name': 'Xiang LIU',
#   'Nationality': 'CHN',
#   'Result': '12.91'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Athens',
#   'Year': '2004',
#   'Medal': 'S',
#   'Name': 'Terrence TRAMMELL',
#   'Nationality': 'USA',
#   'Result': '13.18'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Athens',
#   'Year': '2004',
#   'Medal': 'B',
#   'Name': 'Anier GARCIA',
#   'Nationality': 'CUB',
#   'Result': '13.2'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Atlanta',
#   'Year': '1996',
#   'Medal': 'G',
#   'Name': 'Allen JOHNSON',
#   'Nationality': 'USA',
#   'Result': '12.95'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Atlanta',
#   'Year': '1996',
#   'Medal': 'S',
#   'Name': 'Mark CREAR',
#   'Nationality': 'USA',
#   'Result': '13.09'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Atlanta',
#   'Year': '1996',
#   'Medal': 'B',
#   'Name': 'Florian SCHWARTHOFF',
#   'Nationality': 'GER',
#   'Result': '13.17'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'G',
#   'Name': 'Thomas MUNKELT',
#   'Nationality': 'GDR',
#   'Result': '13.39'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'S',
#   'Name': 'Alejandro CASAÃ\x91AS',
#   'Nationality': 'CUB',
#   'Result': '13.4'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'B',
#   'Name': 'Aleksandr PUCHKOV',
#   'Nationality': 'URS',
#   'Result': '13.44'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Munich',
#   'Year': '1972',
#   'Medal': 'G',
#   'Name': 'Rod MILBURN',
#   'Nationality': 'USA',
#   'Result': '13.24'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Munich',
#   'Year': '1972',
#   'Medal': 'S',
#   'Name': 'Guy DRUT',
#   'Nationality': 'FRA',
#   'Result': '13.34'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Munich',
#   'Year': '1972',
#   'Medal': 'B',
#   'Name': 'Thomas HILL',
#   'Nationality': 'USA',
#   'Result': '13.48'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Tokyo',
#   'Year': '1964',
#   'Medal': 'G',
#   'Name': 'Hayes JONES',
#   'Nationality': 'USA',
#   'Result': '13.6'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Tokyo',
#   'Year': '1964',
#   'Medal': 'S',
#   'Name': 'Blaine LINDGREN',
#   'Nationality': 'USA',
#   'Result': '13.7'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Tokyo',
#   'Year': '1964',
#   'Medal': 'B',
#   'Name': 'Anatoly MIKHAYLOV',
#   'Nationality': 'URS',
#   'Result': '13.7'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Melbourne / Stockholm',
#   'Year': '1956',
#   'Medal': 'G',
#   'Name': 'Lee CALHOUN',
#   'Nationality': 'USA',
#   'Result': '13.5'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Melbourne / Stockholm',
#   'Year': '1956',
#   'Medal': 'S',
#   'Name': 'Jack DAVIS',
#   'Nationality': 'USA',
#   'Result': '13.5'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Melbourne / Stockholm',
#   'Year': '1956',
#   'Medal': 'B',
#   'Name': 'Joel SHANKLE',
#   'Nationality': 'USA',
#   'Result': '14.1'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'London',
#   'Year': '1948',
#   'Medal': 'G',
#   'Name': 'Bill PORTER',
#   'Nationality': 'USA',
#   'Result': '13.9'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'London',
#   'Year': '1948',
#   'Medal': 'S',
#   'Name': 'Clyde SCOTT',
#   'Nationality': 'USA',
#   'Result': '14.1'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'London',
#   'Year': '1948',
#   'Medal': 'B',
#   'Name': 'Craig DIXON',
#   'Nationality': 'USA',
#   'Result': '14.1'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Los Angeles',
#   'Year': '1932',
#   'Medal': 'G',
#   'Name': 'George SALING',
#   'Nationality': 'USA',
#   'Result': '14.6'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Los Angeles',
#   'Year': '1932',
#   'Medal': 'S',
#   'Name': 'Percy BEARD',
#   'Nationality': 'USA',
#   'Result': '14.7'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Los Angeles',
#   'Year': '1932',
#   'Medal': 'B',
#   'Name': 'Donald FINLAY',
#   'Nationality': 'GBR',
#   'Result': '14.8'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Paris',
#   'Year': '1924',
#   'Medal': 'G',
#   'Name': 'Daniel KINSEY',
#   'Nationality': 'USA',
#   'Result': '15.0'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Paris',
#   'Year': '1924',
#   'Medal': 'S',
#   'Name': 'Sidney ATKINSON',
#   'Nationality': 'RSA',
#   'Result': '15.0'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Paris',
#   'Year': '1924',
#   'Medal': 'B',
#   'Name': 'Sten PETTERSSON',
#   'Nationality': 'SWE',
#   'Result': '15.4'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Stockholm',
#   'Year': '1912',
#   'Medal': 'G',
#   'Name': 'Frederick KELLY',
#   'Nationality': 'USA',
#   'Result': '15.1'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Stockholm',
#   'Year': '1912',
#   'Medal': 'S',
#   'Name': 'James WENDELL',
#   'Nationality': 'USA',
#   'Result': '15.2'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Stockholm',
#   'Year': '1912',
#   'Medal': 'B',
#   'Name': 'Martin HAWKINS',
#   'Nationality': 'USA',
#   'Result': '15.3'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'St Louis',
#   'Year': '1904',
#   'Medal': 'G',
#   'Name': 'Frederick SCHULE',
#   'Nationality': 'USA',
#   'Result': '16.0'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'St Louis',
#   'Year': '1904',
#   'Medal': 'S',
#   'Name': 'Thaddeus SHIDELER',
#   'Nationality': 'USA',
#   'Result': '16.3'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'St Louis',
#   'Year': '1904',
#   'Medal': 'B',
#   'Name': 'Lesley ASHBURNER',
#   'Nationality': 'USA',
#   'Result': '16.4'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Athens',
#   'Year': '1896',
#   'Medal': 'G',
#   'Name': 'Thomas CURTIS',
#   'Nationality': 'USA',
#   'Result': '17.6'},
#  {'Gender': 'M',
#   'Event': '110M Hurdles Men',
#   'Location': 'Athens',
#   'Year': '1896',
#   'Medal': 'S',
#   'Name': 'Grantley GOULDING',
#   'Nationality': 'GBR',
#   'Result': '17.7'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'G',
#   'Name': 'Matthew CENTROWITZ',
#   'Nationality': 'USA',
#   'Result': '3:50.00'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'S',
#   'Name': 'Taoufik MAKHLOUFI',
#   'Nationality': 'ALG',
#   'Result': '3:50.11'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'B',
#   'Name': 'Nicholas WILLIS',
#   'Nationality': 'NZL',
#   'Result': '3:50.24'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'G',
#   'Name': 'Asbel Kipruto KIPROP',
#   'Nationality': 'KEN',
#   'Result': '3:33.11'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'S',
#   'Name': 'Nicholas WILLIS',
#   'Nationality': 'NZL',
#   'Result': '3:34.16'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'B',
#   'Name': 'Medhi BAALA',
#   'Nationality': 'FRA',
#   'Result': '3:34.21'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'G',
#   'Name': 'Noah Kiprono NGENYI',
#   'Nationality': 'KEN',
#   'Result': '03:32.07'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'S',
#   'Name': 'Hicham EL GUERROUJ',
#   'Nationality': 'MAR',
#   'Result': '03:32.32'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'B',
#   'Name': 'Bernard LAGAT',
#   'Nationality': 'KEN',
#   'Result': '03:32.44'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'G',
#   'Name': 'Fermin CACHO RUIZ',
#   'Nationality': 'ESP',
#   'Result': '3:40.12'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'S',
#   'Name': 'Rachid EL BASIR',
#   'Nationality': 'MAR',
#   'Result': '3:40.62'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'B',
#   'Name': 'Mohamed Ahmed SULAIMAN',
#   'Nationality': 'QAT',
#   'Result': '3:40.69'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'G',
#   'Name': 'Sebastian COE',
#   'Nationality': 'GBR',
#   'Result': '3:32.53'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'S',
#   'Name': 'Steve CRAM',
#   'Nationality': 'GBR',
#   'Result': '3:33.40'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'B',
#   'Name': 'JosÃ© Manuel ABASCAL',
#   'Nationality': 'ESP',
#   'Result': '3:34.30'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'G',
#   'Name': 'John George WALKER',
#   'Nationality': 'NZL',
#   'Result': '3:39.17'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'S',
#   'Name': 'Ivo VAN DAMME',
#   'Nationality': 'BEL',
#   'Result': '3:39.27'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'B',
#   'Name': 'Paul-Heinz WELLMANN',
#   'Nationality': 'FRG',
#   'Result': '3:39.33'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'G',
#   'Name': 'Kip KEINO',
#   'Nationality': 'KEN',
#   'Result': '3:34.9'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'S',
#   'Name': 'Jim RYUN',
#   'Nationality': 'USA',
#   'Result': '3:37.8'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'B',
#   'Name': 'Bodo TÃ\x9cMMLER',
#   'Nationality': 'FRG',
#   'Result': '3:39.0'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'G',
#   'Name': 'Herb ELLIOTT',
#   'Nationality': 'AUS',
#   'Result': '3:35.6'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'S',
#   'Name': 'Michel JAZY',
#   'Nationality': 'FRA',
#   'Result': '3:38.4'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'B',
#   'Name': 'IstvÃ¡n RÃ\x93ZSAVÃ\x96LGYI',
#   'Nationality': 'HUN',
#   'Result': '3:39.2'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'G',
#   'Name': 'Joseph BARTHEL',
#   'Nationality': 'LUX',
#   'Result': '3:45.2'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'S',
#   'Name': 'Robert MCMILLEN',
#   'Nationality': 'USA',
#   'Result': '3:45.2'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'B',
#   'Name': 'Werner LUEG',
#   'Nationality': 'GER',
#   'Result': '3:45.4'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'G',
#   'Name': 'John LOVELOCK',
#   'Nationality': 'NZL',
#   'Result': '3:47.8'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'S',
#   'Name': 'Glenn CUNNINGHAM',
#   'Nationality': 'USA',
#   'Result': '3:48.4'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'B',
#   'Name': 'Luigi BECCALI',
#   'Nationality': 'ITA',
#   'Result': '3:49.2'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'G',
#   'Name': 'Harri LARVA',
#   'Nationality': 'FIN',
#   'Result': '3:53.2'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'S',
#   'Name': 'Jules LADOUMEGUE',
#   'Nationality': 'FRA',
#   'Result': '3:53.8'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'B',
#   'Name': 'Eino PURJE',
#   'Nationality': 'FIN',
#   'Result': '3:56.4'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'G',
#   'Name': 'Albert HILL',
#   'Nationality': 'GBR',
#   'Result': '4:01.8'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'S',
#   'Name': 'Philip BAKER',
#   'Nationality': 'GBR',
#   'Result': '4:02.4'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'B',
#   'Name': 'Lawrence SHIELDS',
#   'Nationality': 'USA',
#   'Result': '4:03.1'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'London',
#   'Year': '1908',
#   'Medal': 'G',
#   'Name': 'Melvin SHEPPARD',
#   'Nationality': 'USA',
#   'Result': '4:03.4'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'London',
#   'Year': '1908',
#   'Medal': 'S',
#   'Name': 'Harold WILSON',
#   'Nationality': 'GBR',
#   'Result': '4:03.6'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'London',
#   'Year': '1908',
#   'Medal': 'B',
#   'Name': 'Norman HALLOWS',
#   'Nationality': 'GBR',
#   'Result': '4:04.0'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Paris',
#   'Year': '1900',
#   'Medal': 'G',
#   'Name': 'Charles BENNETT',
#   'Nationality': 'GBR',
#   'Result': '4:06.2'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
#   'Location': 'Paris',
#   'Year': '1900',
#   'Medal': 'S',
#   'Name': 'Henri DELOGE',
#   'Nationality': 'FRA',
#   'Result': '4:06.6'},
#  {'Gender': 'M',
#   'Event': '1500M Men',
# ...
#   'Nationality': 'RUS',
#   'Result': '3:43:46'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Atlanta',
#   'Year': '1996',
#   'Medal': 'B',
#   'Name': 'Valentin MASSANA',
#   'Nationality': 'ESP',
#   'Result': '3:44:19'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Seoul',
#   'Year': '1988',
#   'Medal': 'G',
#   'Name': 'Vyacheslav IVANENKO',
#   'Nationality': 'URS',
#   'Result': '3:38:29'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Seoul',
#   'Year': '1988',
#   'Medal': 'S',
#   'Name': 'Ronald WEIGEL',
#   'Nationality': 'GDR',
#   'Result': '3:38:56'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Seoul',
#   'Year': '1988',
#   'Medal': 'B',
#   'Name': 'Hartwig GAUDER',
#   'Nationality': 'GDR',
#   'Result': '3:39:45'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'G',
#   'Name': 'Hartwig GAUDER',
#   'Nationality': 'GDR',
#   'Result': '3:49:24.0'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'S',
#   'Name': 'Jorge LLOPART',
#   'Nationality': 'ESP',
#   'Result': '3:51:25.0'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'B',
#   'Name': 'Yevgeny Mikhaylovich IVCHENKO',
#   'Nationality': 'URS',
#   'Result': '3:56:32.0'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'G',
#   'Name': 'Christoph HÃ\x96HNE',
#   'Nationality': 'GDR',
#   'Result': '4:20:13.6'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'S',
#   'Name': 'Antal KISS',
#   'Nationality': 'HUN',
#   'Result': '4:30:17.0'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'B',
#   'Name': 'Larry YOUNG',
#   'Nationality': 'USA',
#   'Result': '4:31:55.4'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'G',
#   'Name': 'Donald James THOMPSON',
#   'Nationality': 'GBR',
#   'Result': '4:25:30.0'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'S',
#   'Name': 'John LJUNGGREN',
#   'Nationality': 'SWE',
#   'Result': '4:25:47.0'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'B',
#   'Name': 'Abdon PAMICH',
#   'Nationality': 'ITA',
#   'Result': '4:27:55.4'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'G',
#   'Name': 'Giuseppe DORDONI',
#   'Nationality': 'ITA',
#   'Result': '4:28:07.8'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'S',
#   'Name': 'Josef DOLEZAL',
#   'Nationality': 'TCH',
#   'Result': '4:30:17.8'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'B',
#   'Name': 'Antal RÃ\x93KA',
#   'Nationality': 'HUN',
#   'Result': '4:31:27.2'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'G',
#   'Name': 'Harold WHITLOCK',
#   'Nationality': 'GBR',
#   'Result': '4:30:41.4'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'S',
#   'Name': 'Arthur SCHWAB',
#   'Nationality': 'SUI',
#   'Result': '4:32:09.2'},
#  {'Gender': 'M',
#   'Event': '50Km Race Walk Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'B',
#   'Name': 'Adalberts BUBENKO',
#   'Nationality': 'LAT',
#   'Result': '4:32:42.2'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'G',
#   'Name': 'David Lekuta RUDISHA',
#   'Nationality': 'KEN',
#   'Result': '1:42.15'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'S',
#   'Name': 'Taoufik MAKHLOUFI',
#   'Nationality': 'ALG',
#   'Result': '1:42.61'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Rio',
#   'Year': '2016',
#   'Medal': 'B',
#   'Name': 'Clayton MURPHY',
#   'Nationality': 'USA',
#   'Result': '1:42.93'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'G',
#   'Name': 'Wilfred BUNGEI',
#   'Nationality': 'KEN',
#   'Result': '1:44.65'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'S',
#   'Name': 'Ismail Ahmed ISMAIL',
#   'Nationality': 'SUD',
#   'Result': '1:44.70'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Beijing',
#   'Year': '2008',
#   'Medal': 'B',
#   'Name': 'Alfred Kirwa YEGO',
#   'Nationality': 'KEN',
#   'Result': '1:44.82'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'G',
#   'Name': 'Nils SCHUMANN',
#   'Nationality': 'GER',
#   'Result': '01:45.08'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'S',
#   'Name': 'Wilson KIPKETER',
#   'Nationality': 'DEN',
#   'Result': '01:45.14'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Sydney',
#   'Year': '2000',
#   'Medal': 'B',
#   'Name': 'Djabir SAID GUERNI',
#   'Nationality': 'ALG',
#   'Result': '01:45.16'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'G',
#   'Name': 'William TANUI',
#   'Nationality': 'KEN',
#   'Result': '1:43.66'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'S',
#   'Name': 'Nixon KIPROTICH',
#   'Nationality': 'KEN',
#   'Result': '1:43.70'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Barcelona',
#   'Year': '1992',
#   'Medal': 'B',
#   'Name': 'Johnny GRAY',
#   'Nationality': 'USA',
#   'Result': '1:43.97'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'G',
#   'Name': 'Joaquim CRUZ',
#   'Nationality': 'BRA',
#   'Result': '1:43.00'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'S',
#   'Name': 'Sebastian COE',
#   'Nationality': 'GBR',
#   'Result': '1:43.64'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Los Angeles',
#   'Year': '1984',
#   'Medal': 'B',
#   'Name': 'Earl JONES',
#   'Nationality': 'USA',
#   'Result': '1:43.83'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'G',
#   'Name': 'Alberto JUANTORENA',
#   'Nationality': 'CUB',
#   'Result': '1:43.50'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'S',
#   'Name': 'Ivo VAN DAMME',
#   'Nationality': 'BEL',
#   'Result': '1:43.86'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Montreal',
#   'Year': '1976',
#   'Medal': 'B',
#   'Name': 'Richard Charles WOHLHUTER',
#   'Nationality': 'USA',
#   'Result': '1:44.12'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'G',
#   'Name': 'Ralph DOUBELL',
#   'Nationality': 'AUS',
#   'Result': '1:44.3'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'S',
#   'Name': 'Wilson KIPRUGUT',
#   'Nationality': 'KEN',
#   'Result': '1:44.5'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Mexico',
#   'Year': '1968',
#   'Medal': 'B',
#   'Name': 'Thomas Francis FARRELL',
#   'Nationality': 'USA',
#   'Result': '1:45.4'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'G',
#   'Name': 'Peter SNELL',
#   'Nationality': 'NZL',
#   'Result': '1:46.3'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'S',
#   'Name': 'Roger MOENS',
#   'Nationality': 'BEL',
#   'Result': '1:46.5'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Rome',
#   'Year': '1960',
#   'Medal': 'B',
#   'Name': 'George KERR',
#   'Nationality': 'BWI',
#   'Result': '1:47.1'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'G',
#   'Name': 'Mal WHITFIELD',
#   'Nationality': 'USA',
#   'Result': '1:49.2'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'S',
#   'Name': 'Arthur WINT',
#   'Nationality': 'JAM',
#   'Result': '1:49.4'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Helsinki',
#   'Year': '1952',
#   'Medal': 'B',
#   'Name': 'Heinz ULZHEIMER',
#   'Nationality': 'GER',
#   'Result': '1:49.7'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'G',
#   'Name': 'John WOODRUFF',
#   'Nationality': 'USA',
#   'Result': '1:52.9'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'S',
#   'Name': 'Mario LANZI',
#   'Nationality': 'ITA',
#   'Result': '1:53.3'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Berlin',
#   'Year': '1936',
#   'Medal': 'B',
#   'Name': 'Philip EDWARDS',
#   'Nationality': 'CAN',
#   'Result': '1:53.6'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'G',
#   'Name': 'Douglas LOWE',
#   'Nationality': 'GBR',
#   'Result': '1:51.8'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'S',
#   'Name': 'Erik BYLÃ\x89HN',
#   'Nationality': 'SWE',
#   'Result': '1:52.8'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Amsterdam',
#   'Year': '1928',
#   'Medal': 'B',
#   'Name': 'Hermann ENGELHARD',
#   'Nationality': 'GER',
#   'Result': '1:53.2'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'G',
#   'Name': 'Albert HILL',
#   'Nationality': 'GBR',
#   'Result': '1:53.4'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'S',
#   'Name': 'Earl EBY',
#   'Nationality': 'USA',
#   'Result': '1:53.6'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Antwerp',
#   'Year': '1920',
#   'Medal': 'B',
#   'Name': 'Bevil RUDD',
#   'Nationality': 'RSA',
#   'Result': '1:54.0'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'London',
#   'Year': '1908',
#   'Medal': 'G',
#   'Name': 'Melvin SHEPPARD',
#   'Nationality': 'USA',
#   'Result': '1:52.8'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'London',
#   'Year': '1908',
#   'Medal': 'S',
#   'Name': 'Emilio LUNGHI',
#   'Nationality': 'ITA',
#   'Result': '1:54.2'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'London',
#   'Year': '1908',
#   'Medal': 'B',
#   'Name': 'Hanns BRAUN',
#   'Nationality': 'GER',
#   'Result': '1:55.2'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Paris',
#   'Year': '1900',
#   'Medal': 'G',
#   'Name': 'Alfred TYSOE',
#   'Nationality': 'GBR',
#   'Result': '2:01.2'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Paris',
#   'Year': '1900',
#   'Medal': 'S',
#   'Name': 'John CREGAN',
#   'Nationality': 'USA',
#   'Result': '2:01.6'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Paris',
#   'Year': '1900',
#   'Medal': 'B',
#   'Name': 'David HALL',
#   'Nationality': 'USA',
#   'Result': 'None'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'London',
#   'Year': '2012',
#   'Medal': 'G',
#   'Name': 'David Lekuta RUDISHA',
#   'Nationality': 'KEN',
#   'Result': '1:40.91'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'London',
#   'Year': '2012',
#   'Medal': 'S',
#   'Name': 'Nijel AMOS',
#   'Nationality': 'BOT',
#   'Result': '1:41.73'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'London',
#   'Year': '2012',
#   'Medal': 'B',
#   'Name': 'Timothy KITUM',
#   'Nationality': 'KEN',
#   'Result': '1:42.53'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Athens',
#   'Year': '2004',
#   'Medal': 'G',
#   'Name': 'Yuriy BORZAKOVSKIY',
#   'Nationality': 'RUS',
#   'Result': '1:44.45'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Athens',
#   'Year': '2004',
#   'Medal': 'S',
#   'Name': 'Mbulaeni MULAUDZI',
#   'Nationality': 'RSA',
#   'Result': '1:44.61'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Athens',
#   'Year': '2004',
#   'Medal': 'B',
#   'Name': 'Wilson KIPKETER',
#   'Nationality': 'DEN',
#   'Result': '1:44.65'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Atlanta',
#   'Year': '1996',
#   'Medal': 'G',
#   'Name': 'VebjÃ¸rn RODAL',
#   'Nationality': 'NOR',
#   'Result': '1:42.58'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Atlanta',
#   'Year': '1996',
#   'Medal': 'S',
#   'Name': 'Hezekiel SEPENG',
#   'Nationality': 'RSA',
#   'Result': '1:42.74'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Atlanta',
#   'Year': '1996',
#   'Medal': 'B',
#   'Name': 'Fred ONYANCHA',
#   'Nationality': 'KEN',
#   'Result': '1:42.79'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'G',
#   'Name': 'Steve OVETT',
#   'Nationality': 'GBR',
#   'Result': '1:45.4'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'S',
#   'Name': 'Sebastian COE',
#   'Nationality': 'GBR',
#   'Result': '1:45.9'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Moscow',
#   'Year': '1980',
#   'Medal': 'B',
#   'Name': 'Nikolai KIROV',
#   'Nationality': 'URS',
#   'Result': '1:46.0'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Munich',
#   'Year': '1972',
#   'Medal': 'G',
#   'Name': 'David James WOTTLE',
#   'Nationality': 'USA',
#   'Result': '1:45.86'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Munich',
#   'Year': '1972',
#   'Medal': 'S',
#   'Name': 'Yevgeni ARZHANOV',
#   'Nationality': 'URS',
#   'Result': '1:45.89'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Munich',
#   'Year': '1972',
#   'Medal': 'B',
#   'Name': 'Mike BOIT',
#   'Nationality': 'KEN',
#   'Result': '1:46.01'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Tokyo',
#   'Year': '1964',
#   'Medal': 'G',
#   'Name': 'Peter SNELL',
#   'Nationality': 'NZL',
#   'Result': '1:45.1'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Tokyo',
#   'Year': '1964',
#   'Medal': 'S',
#   'Name': 'William CROTHERS',
#   'Nationality': 'CAN',
#   'Result': '1:45.6'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Tokyo',
#   'Year': '1964',
#   'Medal': 'B',
#   'Name': 'Wilson KIPRUGUT',
#   'Nationality': 'KEN',
#   'Result': '1:45.9'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Melbourne / Stockholm',
#   'Year': '1956',
#   'Medal': 'G',
#   'Name': 'Thomas COURTNEY',
#   'Nationality': 'USA',
#   'Result': '1:47.7'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Melbourne / Stockholm',
#   'Year': '1956',
#   'Medal': 'S',
#   'Name': 'Derek JOHNSON',
#   'Nationality': 'GBR',
#   'Result': '1:47.8'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Melbourne / Stockholm',
#   'Year': '1956',
#   'Medal': 'B',
#   'Name': 'Audun BOYSEN',
#   'Nationality': 'NOR',
#   'Result': '1:48.1'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'London',
#   'Year': '1948',
#   'Medal': 'G',
#   'Name': 'Mal WHITFIELD',
#   'Nationality': 'USA',
#   'Result': '1:49.2'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'London',
#   'Year': '1948',
#   'Medal': 'S',
#   'Name': 'Arthur WINT',
#   'Nationality': 'JAM',
#   'Result': '1:49.5'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'London',
#   'Year': '1948',
#   'Medal': 'B',
#   'Name': 'Marcel HANSENNE',
#   'Nationality': 'FRA',
#   'Result': '1:49.8'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Los Angeles',
#   'Year': '1932',
#   'Medal': 'G',
#   'Name': 'Thomas HAMPSON',
#   'Nationality': 'GBR',
#   'Result': '1:49.8'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Los Angeles',
#   'Year': '1932',
#   'Medal': 'S',
#   'Name': 'Alex WILSON',
#   'Nationality': 'CAN',
#   'Result': '1:49.9'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Los Angeles',
#   'Year': '1932',
#   'Medal': 'B',
#   'Name': 'Philip EDWARDS',
#   'Nationality': 'CAN',
#   'Result': 'None'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Paris',
#   'Year': '1924',
#   'Medal': 'G',
#   'Name': 'Douglas LOWE',
#   'Nationality': 'GBR',
#   'Result': '1:52.4'},
#  {'Gender': 'M',
#   'Event': '800M Men',
#   'Location': 'Paris',
#   'Year': '1924',
#   'Medal': 'S',
#   'Name': 'Paul MARTIN',
#   'Nationality': 'SUI',
#   'Result': '1:52.6'},
#  ...]

# %%
# checking data structure of the olympics_data
type(olympics_data)
# Out:
# list

# %%
# import pandas 
import pandas as pd
# pd.read_csv, pd.read_excel, pd.DataFrame
# convert the olympics_data from list format to pandas dataframe
df = pd.DataFrame(olympics_data)
df
# Out:
#      Gender              Event Location  Year Medal                   Name  \
# 0         M         10000M Men      Rio  2016     G          Mohamed FARAH
# 1         M         10000M Men      Rio  2016     S  Paul Kipngetich TANUI
# 2         M         10000M Men      Rio  2016     B           Tamirat TOLA
# 3         M         10000M Men  Beijing  2008     G        Kenenisa BEKELE
# 4         M         10000M Men  Beijing  2008     S         Sileshi SIHINE
# ...     ...                ...      ...   ...   ...                    ...
# 2389      W  Triple Jump Women   Athens  2004     S      Hrysopiyi DEVETZI
# 2390      W  Triple Jump Women   Athens  2004     B       Tatyana LEBEDEVA
# 2391      W  Triple Jump Women  Atlanta  1996     G         Inessa KRAVETS
# 2392      W  Triple Jump Women  Atlanta  1996     S        Inna LASOVSKAYA
# 2393      W  Triple Jump Women  Atlanta  1996     B       Sarka KASPARKOVA
#
#      Nationality    Result
# 0            GBR  25:05.17
# 1            KEN  27:05.64
# 2            ETH  27:06.26
# 3            ETH  27:01.17
# 4            ETH  27:02.77
# ...          ...       ...
# 2389         GRE     15.25
# 2390         RUS     15.14
# 2391         UKR     15.33
# 2392         RUS     14.98
# 2393         CZE     14.98
#
# [2394 rows x 8 columns]

# %%
# check data types
df.info() # object as data types in this case mans string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2394 entries, 0 to 2393
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       2394 non-null   object
#  1   Event        2394 non-null   object
#  2   Location     2394 non-null   object
#  3   Year         2394 non-null   object
#  4   Medal        2394 non-null   object
#  5   Name         2394 non-null   object
#  6   Nationality  2394 non-null   object
#  7   Result       2394 non-null   object
# dtypes: object(8)
# memory usage: 149.8+ KB

# %%
# Extract location details
len(df['Location'].unique())  #to get details
# Out:
# 23

# %%
# check for the size of dataframe
df.shape
# Out:
# (2394, 8)

# %%
# Check for columns
df.columns
# Out:
# Index(['Gender', 'Event', 'Location', 'Year', 'Medal', 'Name', 'Nationality',
#        'Result'],
#       dtype='object')

# %%
# COUNT THE VALUES IN EACH LOCATION
df['Location'].value_counts()
# Out:
# Location
# London                   253
# Los Angeles              181
# Athens                   173
# Rio                      141
# Sydney                   140
# Atlanta                  130
# Beijing                  128
# Barcelona                125
# Moscow                   111
# Paris                    111
# Tokyo                    102
# Rome                      99
# Montreal                  96
# Helsinki                  93
# Munich                    81
# Mexico                    75
# Berlin                    66
# Stockholm                 63
# Melbourne / Stockholm     58
# Amsterdam                 57
# St Louis                  51
# Antwerp                   42
# Seoul                     18
# Name: count, dtype: int64

# %%
df['London']

# %% [markdown]
# ## Introduction
#
# In this section, you'll be introduced to pandas, one of the most powerful and widely used libraries for data analysis in Python.
#
# ## Python Libraries
#
# In some cases, such as opening a JSON file to extract a single value, base Python has all of the functionality you need. Other times when the task is more complex, writing your own code to do it can get overwhelming pretty quickly.
#
# Luckily one of the great benefits of the Python language is that it has a very active open-source community, which means tons of great libraries and frameworks we can use to do the heavy lifting. One of the main reasons that Python is such a great choice for data science is that the scientific community has written plenty of great packages for various advanced purposes. This means that when we use Python, we have access to a wealth of robust, effective tools written and maintained by an army of volunteers and professionals.

# %% [markdown]
# ## Pandas
#
# ![pandas logo](https://curriculum-content.s3.amazonaws.com/data-science/images/pandas.png)
#
# The pandas library will likely be your most-used library over the course of this program. It is a flexible, powerful data analysis library that is especially well-suited to handling tabular data (meaning data that is represented as rows and columns). The name is reminiscent of the term "panel data" as well as "Python data analysis".

# %% [markdown]
# ### `csv.DictReader` to Pandas
#
# The central pandas library feature we will use is the **dataframe** (also styled DataFrame). A dataframe represents tabular data with an integrated index, so data can be selected an manipulated using rows or columns. For some tasks, this means that the syntax can be significantly simpler and more efficient than the equivalent base Python syntax.
#
# Let's go over a quick comparison of using pandas vs. the built-in `csv` module.
#
# We'll use this dataset about Olympic track and field medal-winners from [kaggle](https://www.kaggle.com/jayrav13/olympic-track-field-results). The first five rows look like this:
#
# | Gender | Event      | Location | Year | Medal | Name                  | Nationality | Result   |
# | ------ | ---------- | -------- | ---- | ----- | --------------------- | ----------- | -------- |
# | M      | 10000M Men | Rio      | 2016 | G     | Mohamed FARAH         | GBR         | 25:05.17 |
# | M      | 10000M Men | Rio      | 2016 | S     | Paul Kipngetich TANUI | KEN         | 27:05.64 |
# | M      | 10000M Men | Rio      | 2016 | B     | Tamirat TOLA          | ETH         | 27:06.26 |
# | M      | 10000M Men | Beijing  | 2008 | G     | Kenenisa BEKELE       | ETH         | 27:01.17 |
# | M      | 10000M Men | Beijing  | 2008 | S     | Sileshi SIHINE        | ETH         | 27:02.77 |
#
# To open and read the first 5 lines with the `csv` module, that would look like this:

# %%
import csv

with open("olympic_medals.csv") as f:
    reader = csv.DictReader(f)
    olympics_data = list(reader)

# Print the first 5 rows of data
for index in range(5):
    print(olympics_data[index])
# Out:
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Rio', 'Year': '2016', 'Medal': 'G', 'Name': 'Mohamed FARAH', 'Nationality': 'GBR', 'Result': '25:05.17'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Rio', 'Year': '2016', 'Medal': 'S', 'Name': 'Paul Kipngetich TANUI', 'Nationality': 'KEN', 'Result': '27:05.64'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Rio', 'Year': '2016', 'Medal': 'B', 'Name': 'Tamirat TOLA', 'Nationality': 'ETH', 'Result': '27:06.26'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Beijing', 'Year': '2008', 'Medal': 'G', 'Name': 'Kenenisa BEKELE', 'Nationality': 'ETH', 'Result': '27:01.17'}
# {'Gender': 'M', 'Event': '10000M Men', 'Location': 'Beijing', 'Year': '2008', 'Medal': 'S', 'Name': 'Sileshi SIHINE', 'Nationality': 'ETH', 'Result': '27:02.77'}

# %% [markdown]
# We have a list of dictionaries, where every dictionary has the same keys.
#
# Let's say we want to select all data for the 3rd **row** (record). That's simple enough — we can just use list indexing:

# %%
olympics_data[2]
# Out:
# {'Gender': 'M',
#  'Event': '10000M Men',
#  'Location': 'Rio',
#  'Year': '2016',
#  'Medal': 'B',
#  'Name': 'Tamirat TOLA',
#  'Nationality': 'ETH',
#  'Result': '27:06.26'}

# %% [markdown]
# Now, what if we want to select all data for the 3rd **column** (i.e. the values associated with the `'Location'` keys)? That's not impossible, but it will require some kind of loop or list comprehension. Something like this:

# %%
# Cutting it off at 100 for readability
print([row['Location'] for row in olympics_data][:100])
# Out:
# ['Rio', 'Rio', 'Rio', 'Beijing', 'Beijing', 'Beijing', 'Sydney', 'Sydney', 'Sydney', 'Barcelona', 'Barcelona', 'Barcelona', 'Los Angeles', 'Los Angeles', 'Los Angeles', 'Montreal', 'Montreal', 'Montreal', 'Mexico', 'Mexico', 'Mexico', 'Rome', 'Rome', 'Rome', 'Helsinki', 'Helsinki', 'Helsinki', 'Berlin', 'Berlin', 'Berlin', 'Amsterdam', 'Amsterdam', 'Amsterdam', 'Antwerp', 'Antwerp', 'Antwerp', 'London', 'London', 'London', 'Athens', 'Athens', 'Athens', 'Atlanta', 'Atlanta', 'Atlanta', 'Moscow', 'Moscow', 'Moscow', 'Munich', 'Munich', 'Munich', 'Tokyo', 'Tokyo', 'Tokyo', 'Melbourne / Stockholm', 'Melbourne / Stockholm', 'Melbourne / Stockholm', 'London', 'London', 'London', 'Los Angeles', 'Los Angeles', 'Los Angeles', 'Paris', 'Paris', 'Paris', 'Stockholm', 'Stockholm', 'Stockholm', 'Rio', 'Rio', 'Rio', 'Beijing', 'Beijing', 'Beijing', 'Sydney', 'Sydney', 'Sydney', 'Barcelona', 'Barcelona', 'Barcelona', 'Los Angeles', 'Los Angeles', 'Los Angeles', 'Montreal', 'Montreal', 'Montreal', 'Mexico', 'Mexico', 'Mexico', 'Rome', 'Rome', 'Rome', 'Helsinki', 'Helsinki', 'Helsinki', 'Berlin', 'Berlin', 'Berlin', 'Amsterdam']

# %% [markdown]
# With pandas, accessing columns is just as simple as accessing rows. For example, if we convert `olympics_data` (a list of dictionaries) in a dataframe, then view the first five rows:

# %%
import pandas as pd

df = pd.DataFrame(olympics_data)
df.head()
# Out:
#   Gender       Event Location  Year Medal                   Name Nationality  \
# 0      M  10000M Men      Rio  2016     G          Mohamed FARAH         GBR
# 1      M  10000M Men      Rio  2016     S  Paul Kipngetich TANUI         KEN
# 2      M  10000M Men      Rio  2016     B           Tamirat TOLA         ETH
# 3      M  10000M Men  Beijing  2008     G        Kenenisa BEKELE         ETH
# 4      M  10000M Men  Beijing  2008     S         Sileshi SIHINE         ETH
#
#      Result
# 0  25:05.17
# 1  27:05.64
# 2  27:06.26
# 3  27:01.17
# 4  27:02.77

# %% [markdown]
# We just imported the pandas library as `pd`, the standard alias, then used the `DataFrame` constructor to make a dataframe out of our existing list of dictionaries.
#
# Now we can extract all of the information from the 3rd column with a simpler syntax:

# %%
df['Location']
# Out:
# 0           Rio
# 1           Rio
# 2           Rio
# 3       Beijing
# 4       Beijing
#          ...
# 2389     Athens
# 2390     Athens
# 2391    Atlanta
# 2392    Atlanta
# 2393    Atlanta
# Name: Location, Length: 2394, dtype: object

# %% [markdown]
# But it's also very easy to extract information by row, just like it was with the list of dictionaries:

# %%
df.iloc[2]
# Out:
# Gender                    M
# Event            10000M Men
# Location                Rio
# Year                   2016
# Medal                     B
# Name           Tamirat TOLA
# Nationality             ETH
# Result             27:06.26
# Name: 2, dtype: object

# %% [markdown]
# We can also skip the `csv` module and `olympics_data` variable altogether, and just read the data from the CSV file directly. All you need to do is specify the file path:

# %%
df = pd.read_csv("olympic_medals.csv")
df
# Out:
#      Gender              Event Location  Year Medal                   Name  \
# 0         M         10000M Men      Rio  2016     G          Mohamed FARAH
# 1         M         10000M Men      Rio  2016     S  Paul Kipngetich TANUI
# 2         M         10000M Men      Rio  2016     B           Tamirat TOLA
# 3         M         10000M Men  Beijing  2008     G        Kenenisa BEKELE
# 4         M         10000M Men  Beijing  2008     S         Sileshi SIHINE
# ...     ...                ...      ...   ...   ...                    ...
# 2389      W  Triple Jump Women   Athens  2004     S      Hrysopiyi DEVETZI
# 2390      W  Triple Jump Women   Athens  2004     B       Tatyana LEBEDEVA
# 2391      W  Triple Jump Women  Atlanta  1996     G         Inessa KRAVETS
# 2392      W  Triple Jump Women  Atlanta  1996     S        Inna LASOVSKAYA
# 2393      W  Triple Jump Women  Atlanta  1996     B       Sarka KASPARKOVA
#
#      Nationality    Result
# 0            GBR  25:05.17
# 1            KEN  27:05.64
# 2            ETH  27:06.26
# 3            ETH  27:01.17
# 4            ETH  27:02.77
# ...          ...       ...
# 2389         GRE     15.25
# 2390         RUS     15.14
# 2391         UKR     15.33
# 2392         RUS     14.98
# 2393         CZE     14.98
#
# [2394 rows x 8 columns]

# %% [markdown]
# ### Features of Pandas
#
# The code snippets above demonstrate two of the library highlights from the pandas [about page](https://pandas.pydata.org/about/):
#
# * A fast and efficient **DataFrame** object for data manipulation with integrated indexing;
# * Tools for **reading and writing data between in-memory data structures and different formats**: CSV and text files, Microsoft Excel, SQL databases, and the fast HDF5 format;
#
# Other highlights include:
#
# * Intelligent data alignment and integrated **handling of missing data**: gain automatic label-based alignment in computations and easily manipulate messy data into an orderly form;
# * Flexible **reshaping and pivoting** of data sets;
# * Intelligent label-based **slicing**, fancy indexing, and **subsetting** of large data sets;
# * Aggregating or transforming data with a powerful **group by** engine allowing split-apply-combine operations on data sets;
# * High performance **merging and joining** of data sets;
# * **Time series**-functionality: date range generation and frequency conversion, moving window statistics, date shifting and lagging. Even create domain-specific time offsets and join time series without losing data;
# * Highly **optimized for performance**, with critical code paths written in Cython or C.
#
# We will begin to dive into these features in this section!
